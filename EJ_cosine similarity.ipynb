# %%
import getpass
import pandas as pd
from pymongo import MongoClient

# %%
password = getpass.getpass("MongoDB password: ")
# Out:
# MongoDB password:  ········

# %%
client = MongoClient(f'mongodb://book_group:{password}@macragge.reika.io:47017/?authSource=books')

# %%
db = client['books']
collection = db['books']

# %%
# Fetch data from MongoDB
query = {'random': {'$lte': 40}}
data = list(collection.find(query))  # Retrieve documents as a list of dictionaries

# %%
# Create DataFrame and preview
df = pd.DataFrame(data)

# Filter the DataFrame to only include rows where 'language_code' is 'eng'
df = df[df['language_code'] == "eng"]

# Display the first few rows of the filtered DataFrame
df.head()
# Out:
#                          _id        isbn text_reviews_count    series
# 1   66df9d075a178eb80fbd4d51  0970190719                 11        []  \
# 3   66df9d075a178eb80fbd4d8f  0590421921                  9  [155231]
# 4   66df9d075a178eb80fbd4d9b  0399216154                  2  [361869]
# 10  66df9d085a178eb80fbd4e50  1851520198                  2        []
# 12  66df9d085a178eb80fbd4e9c                              3        []
#
#    country_code language_code
# 1            US           eng  \
# 3            US           eng
# 4            US           eng
# 10           US           eng
# 12           US           eng
#
#                                       popular_shelves asin is_ebook
# 1   [{'count': '66', 'name': 'to-read'}, {'count':...         false  \
# 3   [{'count': '38', 'name': 'to-read'}, {'count':...         false
# 4   [{'count': '25', 'name': 'to-read'}, {'count':...         false
# 10  [{'count': '93', 'name': 'to-read'}, {'count':...         false
# 12  [{'count': '10', 'name': 'to-read'}, {'count':...         false
#
#    average_rating  ... publication_year
# 1            4.06  ...             2002  \
# 3            4.07  ...             1989
# 4            4.30  ...             1989
# 10           4.38  ...             1986
# 12           4.17  ...             2016
#
#                                                   url
# 1   https://www.goodreads.com/book/show/1006140.Th...  \
# 3   https://www.goodreads.com/book/show/1151567.Dr...
# 4   https://www.goodreads.com/book/show/1076044.An...
# 10  https://www.goodreads.com/book/show/2974706-th...
# 12  https://www.goodreads.com/book/show/29356054-a...
#
#                                             image_url   book_id ratings_count
# 1   https://s.gr-assets.com/assets/nophoto/book/11...   1006140            27  \
# 3   https://images.gr-assets.com/books/1326125976m...   1151567           229
# 4   https://images.gr-assets.com/books/1303608064m...   1076044            25
# 10  https://s.gr-assets.com/assets/nophoto/book/11...   2974706            10
# 12  https://images.gr-assets.com/books/1456640073m...  29356054            18
#
#      work_id                             title
# 1     652659                          The Tree  \
# 3    1139050  Drina's Dancing Year (Drina, #2)
# 4     583367              Anno's Math Games II
# 10    114888     The Arthur Rackham Fairy Book
# 12  49599175        A Soldier, a Dog and a Boy
#
#                 title_without_series     genre random
# 1                           The Tree  children     26
# 3   Drina's Dancing Year (Drina, #2)  children     24
# 4               Anno's Math Games II  children     38
# 10     The Arthur Rackham Fairy Book  children     18
# 12        A Soldier, a Dog and a Boy  children     36
#
# [5 rows x 32 columns]

# %%
df['average_rating'] = df['average_rating'].astype(float)

# %%
#Dataframe/pivot table with index of title and genre as user id values of book ratings
pt = df.pivot_table(index='title', columns='genre', values='average_rating', aggfunc='mean')
pt.fillna(0,inplace=True)

# %%
pt.tail(20)
# Out:
# genre                                               children  comics_graphic
# title
# pollen and the storm                                    0.00            0.00  \
# tea's aftertaste                                        0.00            0.00
# the Beastly Pirates                                     3.56            0.00
# the marahani pearls                                     0.00            0.00
# the single girls to do list                             0.00            0.00
# the throne of tara                                      0.00            0.00
# the very helpful monsters                               3.96            0.00
# the wonderfull wizard of oz                             3.98            0.00
# unvamped                                                0.00            0.00
# xxxHolic, Vol. 18 (xxxHOLiC, #18)                       0.00            4.32
# £6.19 per Witching Hour (Paranormal Personnel S...      0.00            0.00
# Ōoku: The Inner Chambers, Volume 9 (Ōoku: The I...      0.00            0.00
# Δρακοδαμαστές (Δρακοδαμαστές, #1)                       0.00            0.00
# Η τελευταία διάλεξη                                     0.00            0.00
# Ночное кино                                             0.00            0.00
# Танатонавты                                             0.00            0.00
# ثورة الموتي                                             0.00            0.00
# چشم بهشتی                                               0.00            0.00
# ’Til it Bleeds                                          0.00            0.00
# 飼主は悪魔 [Kainushi wa Akuma], Vol. 2                       0.00            0.00
#
# genre                                               fantasy_paranormal
# title
# pollen and the storm                                              0.00  \
# tea's aftertaste                                                  0.00
# the Beastly Pirates                                               0.00
# the marahani pearls                                               0.00
# the single girls to do list                                       0.00
# the throne of tara                                                3.54
# the very helpful monsters                                         0.00
# the wonderfull wizard of oz                                       0.00
# unvamped                                                          3.38
# xxxHolic, Vol. 18 (xxxHOLiC, #18)                                 0.00
# £6.19 per Witching Hour (Paranormal Personnel S...                3.50
# Ōoku: The Inner Chambers, Volume 9 (Ōoku: The I...                0.00
# Δρακοδαμαστές (Δρακοδαμαστές, #1)                                 3.40
# Η τελευταία διάλεξη                                               0.00
# Ночное кино                                                       0.00
# Танатонавты                                                       4.02
# ثورة الموتي                                                       0.00
# چشم بهشتی                                                         0.00
# ’Til it Bleeds                                                    3.69
# 飼主は悪魔 [Kainushi wa Akuma], Vol. 2                                 0.00
#
# genre                                               history_biography
# title
# pollen and the storm                                             0.00  \
# tea's aftertaste                                                 0.00
# the Beastly Pirates                                              0.00
# the marahani pearls                                              3.66
# the single girls to do list                                      0.00
# the throne of tara                                               0.00
# the very helpful monsters                                        0.00
# the wonderfull wizard of oz                                      0.00
# unvamped                                                         0.00
# xxxHolic, Vol. 18 (xxxHOLiC, #18)                                0.00
# £6.19 per Witching Hour (Paranormal Personnel S...               0.00
# Ōoku: The Inner Chambers, Volume 9 (Ōoku: The I...               4.28
# Δρακοδαμαστές (Δρακοδαμαστές, #1)                                0.00
# Η τελευταία διάλεξη                                              4.25
# Ночное кино                                                      0.00
# Танатонавты                                                      0.00
# ثورة الموتي                                                      3.73
# چشم بهشتی                                                        0.00
# ’Til it Bleeds                                                   0.00
# 飼主は悪魔 [Kainushi wa Akuma], Vol. 2                                0.00
#
# genre                                               mystery_thriller_crime
# title
# pollen and the storm                                                  0.00  \
# tea's aftertaste                                                      0.00
# the Beastly Pirates                                                   0.00
# the marahani pearls                                                   0.00
# the single girls to do list                                           0.00
# the throne of tara                                                    0.00
# the very helpful monsters                                             0.00
# the wonderfull wizard of oz                                           0.00
# unvamped                                                              0.00
# xxxHolic, Vol. 18 (xxxHOLiC, #18)                                     0.00
# £6.19 per Witching Hour (Paranormal Personnel S...                    0.00
# Ōoku: The Inner Chambers, Volume 9 (Ōoku: The I...                    0.00
# Δρακοδαμαστές (Δρακοδαμαστές, #1)                                     0.00
# Η τελευταία διάλεξη                                                   0.00
# Ночное кино                                                           3.78
# Танатонавты                                                           0.00
# ثورة الموتي                                                           0.00
# چشم بهشتی                                                             0.00
# ’Til it Bleeds                                                        0.00
# 飼主は悪魔 [Kainushi wa Akuma], Vol. 2                                     0.00
#
# genre                                               poetry  romance
# title
# pollen and the storm                                   4.5     0.00  \
# tea's aftertaste                                       5.0     0.00
# the Beastly Pirates                                    0.0     0.00
# the marahani pearls                                    0.0     0.00
# the single girls to do list                            0.0     3.94
# the throne of tara                                     0.0     0.00
# the very helpful monsters                              0.0     0.00
# the wonderfull wizard of oz                            0.0     0.00
# unvamped                                               0.0     0.00
# xxxHolic, Vol. 18 (xxxHOLiC, #18)                      0.0     0.00
# £6.19 per Witching Hour (Paranormal Personnel S...     0.0     0.00
# Ōoku: The Inner Chambers, Volume 9 (Ōoku: The I...     0.0     0.00
# Δρακοδαμαστές (Δρακοδαμαστές, #1)                      0.0     0.00
# Η τελευταία διάλεξη                                    0.0     0.00
# Ночное кино                                            0.0     0.00
# Танатонавты                                            0.0     0.00
# ثورة الموتي                                            0.0     0.00
# چشم بهشتی                                              0.0     0.00
# ’Til it Bleeds                                         0.0     0.00
# 飼主は悪魔 [Kainushi wa Akuma], Vol. 2                      0.0     4.42
#
# genre                                               young_adult
# title
# pollen and the storm                                       0.00
# tea's aftertaste                                           0.00
# the Beastly Pirates                                        0.00
# the marahani pearls                                        0.00
# the single girls to do list                                0.00
# the throne of tara                                         0.00
# the very helpful monsters                                  0.00
# the wonderfull wizard of oz                                0.00
# unvamped                                                   0.00
# xxxHolic, Vol. 18 (xxxHOLiC, #18)                          0.00
# £6.19 per Witching Hour (Paranormal Personnel S...         0.00
# Ōoku: The Inner Chambers, Volume 9 (Ōoku: The I...         0.00
# Δρακοδαμαστές (Δρακοδαμαστές, #1)                          0.00
# Η τελευταία διάλεξη                                        0.00
# Ночное кино                                                0.00
# Танатонавты                                                0.00
# ثورة الموتي                                                0.00
# چشم بهشتی                                                  3.71
# ’Til it Bleeds                                             0.00
# 飼主は悪魔 [Kainushi wa Akuma], Vol. 2                          0.00

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (21633, 21633)

# %%
import numpy as np
def recommendation(book_name):
    # Fetching Index
    if book_name in list(pt.index):
        index = np.where(np.array(list(pt.index)) == book_name)[0][0]
        
        # Retrieve similarity scores for the specific book
        similarity_scores_for_book = similarity_scores[index]
        
        # Sort similar items based on the specific book's similarity scores
        similar_items = sorted(list(enumerate(similarity_scores_for_book)), reverse=True, key=lambda x: x[1])[1:9]
        
        data = []
        for i in similar_items:
            title = pt.index[i[0]]
            temp_df = df[df['title'] == title]
            item = list(temp_df.drop_duplicates('title')['title'].values)
            data.append(item)
        
    else:
        print(f"The book '{book_name}' is not found in the index.")

    return data

# %%
recommendation("the marahani pearls")
# Out:
# [['11.22.63'],
#  ['11/22/63'],
#  ['1177 B.C.: The Year Civilization Collapsed'],
#  ['11th Hour Rose (Langston Brothers #3)'],
#  ['1776'],
#  ['1929 (The 1929 Series, #1)'],
#  ['1940s: Decades of the 20th Century'],
#  ['23 Years: A Study of the Prophetic Career of Mohammad']]

# %%
client.close()
