# %%
import getpass
import pandas as pd
from pymongo import MongoClient

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
password = getpass.getpass("MongoDB password: ")
# Out:
# MongoDB password:  ········

# %%
client = MongoClient(f'mongodb://book_group:{password}@macragge.reika.io:47017/?authSource=books')

# %%
db = client['books']
collection = db['books']

# %%
# Fetch data from MongoDB
query = {'random': {'$lte': 10}}
data = list(collection.find(query))  # Retrieve documents as a list of dictionaries

# %%
# Create DataFrame and preview
df = pd.DataFrame(data)

# Filter the DataFrame to only include rows where 'language_code' is 'eng'
df = df[df['language_code'] == "eng"]

# Display the first few rows of the filtered DataFrame
df.head()
# Out:
#                          _id        isbn text_reviews_count    series
# 3   66df9d085a178eb80fbd4e9f  1849412235                  1  [499526]  \
# 8   66df9d085a178eb80fbd4fea  0394849736                  8  [638089]
# 15  66df9d0a5a178eb80fbd54b2  159707487X                 13  [614823]
# 16  66df9d0a5a178eb80fbd5505                             18  [355505]
# 17  66df9d0a5a178eb80fbd5520  0545060613                 11        []
#
#    country_code language_code
# 3            US           eng  \
# 8            US           eng
# 15           US           eng
# 16           US           eng
# 17           US           eng
#
#                                       popular_shelves asin is_ebook
# 3   [{'count': '15', 'name': 'to-read'}, {'count':...         false  \
# 8   [{'count': '88', 'name': 'to-read'}, {'count':...         false
# 15  [{'count': '15', 'name': 'to-read'}, {'count':...         false
# 16  [{'count': '301', 'name': 'to-read'}, {'count'...         false
# 17  [{'count': '33', 'name': 'to-read'}, {'count':...         false
#
#    average_rating  ... publication_year
# 3            4.23  ...             2010  \
# 8            4.04  ...             1981
# 15           4.11  ...             2013
# 16           4.36  ...             2013
# 17           3.70  ...             2008
#
#                                                   url
# 3   https://www.goodreads.com/book/show/9501773-th...  \
# 8   https://www.goodreads.com/book/show/1350015.Pe...
# 15  https://www.goodreads.com/book/show/17454804-a...
# 16  https://www.goodreads.com/book/show/13540858-f...
# 17  https://www.goodreads.com/book/show/5944673-th...
#
#                                             image_url   book_id ratings_count
# 3   https://s.gr-assets.com/assets/nophoto/book/11...   9501773            31  \
# 8   https://s.gr-assets.com/assets/nophoto/book/11...   1350015           173
# 15  https://images.gr-assets.com/books/1413131666m...  17454804            89
# 16  https://images.gr-assets.com/books/1331685546m...  13540858           402
# 17  https://images.gr-assets.com/books/1259031059m...   5944673            23
#
#      work_id                            title
# 3   14387351  The Adventures of Mrs Pepperpot  \
# 8   40872087              Peter Pan and Wendy
# 15  24344930      Ariol #3: Happy as a Pig...
# 16  19103974   Famous (Canterwood Crest, #18)
# 17   6117184           The Silly Turkey Party
#
#                title_without_series     genre random
# 3   The Adventures of Mrs Pepperpot  children      0
# 8               Peter Pan and Wendy  children      7
# 15      Ariol #3: Happy as a Pig...  children      5
# 16   Famous (Canterwood Crest, #18)  children      3
# 17           The Silly Turkey Party  children      7
#
# [5 rows x 32 columns]

# %%
df['average_rating'] = df['average_rating'].astype(float)

# %%
#Dataframe/pivot table with index of title and genre as user id values of book ratings
pt = df.pivot_table(index='title', columns='genre', values='average_rating', aggfunc='mean')
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# genre                              children  comics_graphic
# title
# "Verified Kill" (Assassins, #1)        0.00             0.0  \
# $10,000,000 Marriage Proposal          0.00             0.0
# 'Salem's Lot                           0.00             0.0
# 'Til Death (Conversion, #3)            0.00             0.0
# ...all five... a true story            0.00             0.0
# ...                                     ...             ...
# the single girls to do list            0.00             0.0
# the throne of tara                     0.00             0.0
# the very helpful monsters              3.96             0.0
# چشم بهشتی                              0.00             0.0
# 飼主は悪魔 [Kainushi wa Akuma], Vol. 2      0.00             0.0
#
# genre                              fantasy_paranormal  history_biography
# title
# "Verified Kill" (Assassins, #1)                  0.00                0.0  \
# $10,000,000 Marriage Proposal                    0.00                0.0
# 'Salem's Lot                                     0.00                0.0
# 'Til Death (Conversion, #3)                      4.19                0.0
# ...all five... a true story                      0.00                0.0
# ...                                               ...                ...
# the single girls to do list                      0.00                0.0
# the throne of tara                               3.54                0.0
# the very helpful monsters                        0.00                0.0
# چشم بهشتی                                        0.00                0.0
# 飼主は悪魔 [Kainushi wa Akuma], Vol. 2                0.00                0.0
#
# genre                              mystery_thriller_crime  poetry  romance
# title
# "Verified Kill" (Assassins, #1)                      0.00     0.0     3.88  \
# $10,000,000 Marriage Proposal                        0.00     0.0     3.24
# 'Salem's Lot                                         3.99     0.0     0.00
# 'Til Death (Conversion, #3)                          0.00     0.0     0.00
# ...all five... a true story                          4.07     0.0     0.00
# ...                                                   ...     ...      ...
# the single girls to do list                          0.00     0.0     3.94
# the throne of tara                                   0.00     0.0     0.00
# the very helpful monsters                            0.00     0.0     0.00
# چشم بهشتی                                            0.00     0.0     0.00
# 飼主は悪魔 [Kainushi wa Akuma], Vol. 2                    0.00     0.0     4.42
#
# genre                              young_adult
# title
# "Verified Kill" (Assassins, #1)           0.00
# $10,000,000 Marriage Proposal             0.00
# 'Salem's Lot                              0.00
# 'Til Death (Conversion, #3)               0.00
# ...all five... a true story               0.00
# ...                                        ...
# the single girls to do list               0.00
# the throne of tara                        0.00
# the very helpful monsters                 0.00
# چشم بهشتی                                 3.71
# 飼主は悪魔 [Kainushi wa Akuma], Vol. 2         0.00
#
# [5965 rows x 8 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (5965, 5965)

# %%
def recommendation(book_name):
    # Fetching Index
    if book_name in list(pt.index):
        index = np.where(np.array(list(pt.index)) == book_name)[0][0]
        
        # Retrieve similarity scores for the specific book
        similarity_scores_for_book = similarity_scores[index]
        
        # Sort similar items based on the specific book's similarity scores
        similar_items = sorted(list(enumerate(similarity_scores_for_book)), reverse=True, key=lambda x: x[1])[1:9]
        
        data = []
        for i in similar_items:
            title = pt.index[i[0]]
            temp_df = df[df['title'] == title]
            item = list(temp_df.drop_duplicates('title')['title'].values)
            data.append(item)
        
    else:
        print(f"The book '{book_name}' is not found in the index.")

    return data

# %%
recommendation("the very helpful monsters")
# Out:
# [['A Chair for My Mother'],
#  ['A Dog for Everyone'],
#  ['A Fairy Went A-Marketing'],
#  ['A Full House: An Austin Family Christmas (Austin Family, #5.6)'],
#  ['A Is For Asia'],
#  ['A Letter to Amy'],
#  ['A Little Princess'],
#  ['A Pattern Of Roses']]

# %%
client.close()
